# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
eq=pd.read_csv("japanearthquake.csv")

# %%
eq.shape
# Out:
# (215, 22)

# %%
eq.head()
# Out:
#                        time  latitude  longitude   depth   mag magType   nst  \
# 0  2021-08-16T04:35:51.680Z   17.8435   -66.8898   12.00  2.57      md  17.0
# 1  2021-08-16T01:33:40.550Z   17.9775   -66.7873   17.00  2.56      md  14.0
# 2  2021-08-15T22:10:12.050Z   17.9833   -66.7738   11.00  2.75      md  17.0
# 3  2021-08-15T21:38:27.410Z   18.2806   -68.0030  103.00  3.64      md  11.0
# 4  2021-08-15T16:05:05.782Z   18.5392   -73.5810   12.04  4.10      mb   NaN
#
#    gap    dmin   rms  ...                   updated  \
# 0  231  0.1993  0.21  ...  2021-08-16T05:00:30.524Z
# 1  179  0.1925  0.15  ...  2021-08-16T06:14:16.458Z
# 2  175  0.1778  0.12  ...  2021-08-16T00:56:25.321Z
# 3  156  0.4445  0.21  ...  2021-08-16T06:21:13.582Z
# 4   95  1.7390  0.49  ...  2021-08-15T17:08:23.040Z
#
#                                         place        type horizontalError  \
# 0             14 km S of Guánica, Puerto Rico  earthquake            0.73
# ...

# %%
#eq.describe

# %%
eq.head()
# Out:
#                        time  latitude  longitude   depth   mag magType   nst  \
# 0  2021-08-16T04:35:51.680Z   17.8435   -66.8898   12.00  2.57      md  17.0
# 1  2021-08-16T01:33:40.550Z   17.9775   -66.7873   17.00  2.56      md  14.0
# 2  2021-08-15T22:10:12.050Z   17.9833   -66.7738   11.00  2.75      md  17.0
# 3  2021-08-15T21:38:27.410Z   18.2806   -68.0030  103.00  3.64      md  11.0
# 4  2021-08-15T16:05:05.782Z   18.5392   -73.5810   12.04  4.10      mb   NaN
#
#    gap    dmin   rms  ...                   updated  \
# 0  231  0.1993  0.21  ...  2021-08-16T05:00:30.524Z
# 1  179  0.1925  0.15  ...  2021-08-16T06:14:16.458Z
# 2  175  0.1778  0.12  ...  2021-08-16T00:56:25.321Z
# 3  156  0.4445  0.21  ...  2021-08-16T06:21:13.582Z
# 4   95  1.7390  0.49  ...  2021-08-15T17:08:23.040Z
#
#                                         place        type horizontalError  \
# 0             14 km S of Guánica, Puerto Rico  earthquake            0.73
# ...

# %%
eq['nst']=eq['nst'].fillna(0)
eq['rms']=eq['rms'].fillna(0)

# %%
eq.head()
# Out:
#                        time  latitude  longitude   depth   mag magType   nst  \
# 0  2021-08-16T04:35:51.680Z   17.8435   -66.8898   12.00  2.57      md  17.0
# 1  2021-08-16T01:33:40.550Z   17.9775   -66.7873   17.00  2.56      md  14.0
# 2  2021-08-15T22:10:12.050Z   17.9833   -66.7738   11.00  2.75      md  17.0
# 3  2021-08-15T21:38:27.410Z   18.2806   -68.0030  103.00  3.64      md  11.0
# 4  2021-08-15T16:05:05.782Z   18.5392   -73.5810   12.04  4.10      mb   0.0
#
#    gap    dmin   rms  ...                   updated  \
# 0  231  0.1993  0.21  ...  2021-08-16T05:00:30.524Z
# 1  179  0.1925  0.15  ...  2021-08-16T06:14:16.458Z
# 2  175  0.1778  0.12  ...  2021-08-16T00:56:25.321Z
# 3  156  0.4445  0.21  ...  2021-08-16T06:21:13.582Z
# 4   95  1.7390  0.49  ...  2021-08-15T17:08:23.040Z
#
#                                         place        type horizontalError  \
# 0             14 km S of Guánica, Puerto Rico  earthquake            0.73
# ...

# %%
x=eq.iloc[:,[1,2,7]].values
y=eq.iloc[:,9:10].values

# %%
print(x)
#print(y)
# Out:
# [[ 17.8435     -66.8898     231.        ]
#  [ 17.9775     -66.7873     179.        ]
#  [ 17.9833     -66.7738     175.        ]
#  [ 18.2806     -68.003      156.        ]
#  [ 18.5392     -73.581       95.        ]
#  [ 17.9595     -66.9238     191.        ]
#  [ 19.3821     -64.7703     323.        ]
#  [ 18.4762     -73.7504      42.        ]
#  [ 17.8825     -66.8861     229.        ]
#  [ 18.5103     -73.6685      75.        ]
#  [ 17.8476     -66.8896     250.        ]
#  [ 17.8736     -66.8875     231.        ]
#  [ 18.4388     -74.0965      83.        ]
#  [ 17.8411     -66.8851     250.        ]
#  [ 17.8511     -66.886      225.        ]
#  [ 18.3711     -74.0992      34.        ]
#  [ 18.5997     -73.5811      28.        ]
#  [ 17.9881     -66.9516     179.        ]
#  [ 18.5174     -74.0251      76.        ]
#  [ 18.4717     -74.0298      79.        ]
#  [ 18.0375     -66.7931     117.        ]
#  [ 18.0308     -66.7996     134.        ]
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regg=LinearRegression()
regg.fit(x_train,y_train)
#pickle.dump(regg,open('model.pkl','wb'))
# Out:
# LinearRegression()

# %%
#model=pickle.load(open('model.pkl','rb'))
#print(model)

# %%
print(regg.intercept_)
# Out:
# [-8.67977244]

# %%
print(regg.coef_)
# Out:
# [[ 0.20847235 -0.07685851 -0.00023054]]

# %%
ypre=regg.predict(x_test)
#print(ypre)

# %%
print("Mean squared error: %.2f" % np.mean((regg.predict(x_test) - y_test) ** 2))
print('Variance score: %.2f' % regg.score(x_test, y_test))
r2_score = regg.score(x_test,y_test)
print(r2_score)
# Out:
# Mean squared error: 0.02
# Variance score: 0.75
# 0.7484483883643904

# %%
para=[[18.5392,-73.5810,231]]

# %%
predeq=regg.predict(para)
print(predeq)
# Out:
# [[0.78720822]]

# %%
if(predeq> 0.3):
    print("earthquake")
else:
    print("no earthquake")
# Out:
# earthquake
